# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Preprocessing-the-Dataset" data-toc-modified-id="Preprocessing-the-Dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing the Dataset</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Likes-from-object-to-numeric" data-toc-modified-id="Likes-from-object-to-numeric-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Likes from object to numeric</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Budget-from-object-to-numeric" data-toc-modified-id="Budget-from-object-to-numeric-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Budget from object to numeric</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Country" data-toc-modified-id="Country-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Country</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Duration" data-toc-modified-id="Duration-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Duration</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Language" data-toc-modified-id="Language-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Language</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Genres" data-toc-modified-id="Genres-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Genres</a></span></li><li><span><a href="http://localhost:8888/notebooks/Preprocessing.ipynb#Keywords-&amp;-Storyline" data-toc-modified-id="Keywords-&amp;-Storyline-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Keywords &amp; Storyline</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preprocessing the Dataset

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data_from_scrapping.csv', sep=";", encoding='utf-8')

# %%
data.shape
# Out:
# (5153, 27)

# %%
data.head()
# Out:
#    Unnamed: 0 Actor_1_id Actor_1_like     Actor_1_name Actor_2_id  \
# 0           0  nm0941777          5.3  Sam Worthington  nm0757855
# 1           1  nm3766090           13      Doug Walker  nm3597657
# 2           2  nm0000136           40      Johnny Depp  nm0089217
# 3           3  nm0185819          8.5     Daniel Craig  nm0910607
# 4           4  nm0000288          NaN   Christian Bale  nm0362766
#
#   Actor_2_like     Actor_2_name Actor_3_id Actor_3_like      Actor_3_name  \
# 0          NaN      Zoe Saldana  nm0000244          5.3  Sigourney Weaver
# 1            1       Rob Walker        NaN          NaN               NaN
# 2          5.1    Orlando Bloom  nm0461136           40   Keira Knightley
# 3           11  Christoph Waltz  nm2244205          8.5       Léa Seydoux
# 4          NaN        Tom Hardy  nm0004266          NaN     Anne Hathaway
#
#     ...              Gross IMDb_critics IMDb_rating  \
# 0   ...    2,787,965,087,       983,961         7.8
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Actor_1_id           25
# Actor_1_like        825
# Actor_1_name         25
# Actor_2_id           38
# Actor_2_like        638
# Actor_2_name         38
# Actor_3_id           46
# Actor_3_like        840
# Actor_3_name         46
# Budget              770
# Country              38
# Director_id         134
# Director_like       577
# Director_name       134
# Duration           3146
# Genres                0
# Gross              2797
# IMDb_critics         53
# IMDb_rating          53
# Keywords              0
# Language             46
# Movie_name            0
# Movie_url             0
# Opening Weekend    1118
# Storyline            42
# Year                156
# dtype: int64

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
features_for_model = ["Actor_1_like", "Actor_2_like", "Actor_3_like", "Budget", "Country", "Director_like", "Duration"
                     ,"Genres", "Keywords", "Language", "Storyline", "Year"]
target_gross = ["Gross"]
target_imdb = ["IMDb_rating"]
target_opening = ["Opening Weekend"]

# %%
X = data[features_for_model]
y = data[target_gross]

# %%
X.dtypes
# Out:
# Actor_1_like      object
# Actor_2_like      object
# Actor_3_like      object
# Budget           float64
# Country           object
# Director_like     object
# Duration          object
# Genres            object
# Keywords          object
# Language          object
# Storyline         object
# Year             float64
# dtype: object

# %% [markdown]
# ## Likes from object to numeric

# %%
pd.to_numeric(X['Actor_1_like'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric (pandas/_libs/lib.c:56156)()
#
# ValueError: Unable to parse string "on"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d8b5c4dccbeb> in <module>()
# ----> 1 pd.to_numeric(X['Actor_1_like'])
#
# ~/.virtualenvs/romainvenv/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# ...

# %% [markdown]
# ## Budget from object to numeric

# %%
X['Budget'][0].replace(',', '')
# Out:
# '237000000'

# %%
X['Budget'].values
# Out:
# array(['237,000,000', nan, '300,000,000', ..., nan, '1,400', '1,100'],
#       dtype=object)

# %%
X["Budget"] = X["Budget"].str.replace(',', '').astype(float)
# Out:
# /Users/Romain/.virtualenvs/romainvenv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Country

# %%
X['Country'].unique()
# Out:
# array(['UK', nan, 'USA', 'New Zealand', 'Canada', 'China', 'Japan',
#        'Australia', 'France', 'Belgium', 'Germany', 'Spain', 'New Line',
#        'South Africa', 'Czech Republic', 'Mexico', 'Finland', 'Hong Kong',
#        'Malta', 'India', 'Soviet Union', 'South Korea', 'Peru',
#        'Netherlands', 'Italy', 'Russia', 'Aruba', 'Denmark', 'Libya',
#        'Ireland', 'Iceland', 'Romania', 'West Germany', 'Chile',
#        'Argentina', 'Hungary', 'Panama', 'Switzerland', 'Sweden',
#        'Norway', 'Taiwan', 'Official site', 'Cambodia', 'Thailand',
#        'Slovakia', 'Bulgaria', 'Iran', 'Poland', 'Georgia', 'Austria',
#        'Turkey', 'Nigeria', 'Brazil', 'Bahamas', 'Colombia', 'Israel',
#        'Kyrgyzstan', 'Indonesia', 'Pakistan', 'Puerto Rico', 'Slovenia',
#        'Afghanistan', 'Dominican Republic', 'Greece', 'Cameroon',
#        'United Arab Emirates', 'Kenya', 'Philippines'], dtype=object)

# %%
len(X['Country'].unique())
# Out:
# 68

# %%
X['label_country'] = X['Country']
cleanup_countries = {"label_country": {"UK": 0, 'France':0, 'Belgium':0, 'Germany':0, 'Spain':0, 'Czech Republic':0,
                                       'Finland':0, 'Malta':0, 'Soviet Union':0, 'Netherlands':0, 'Italy':0,
                                       'Russia':0,'Denmark':0,'Ireland':0, 'Iceland':0, 'Romania':0, 'West Germany':0,
                                       'Hungary':0,'Switzerland':0, 'Sweden':0,'Norway':0,'Slovakia':0, 'Bulgaria':0,
                                       'Poland':0, 'Georgia':0, 'Austria':0,'Turkey':0,'Israel':0,'Slovenia':0,
                                       'Greece':0,
                                         "USA": 1, "Canada":1, 'Mexico':1,'Peru':1,'Aruba':1,'Chile':1,'Argentina':1,
                                       'Panama':1, 'Brazil':1, 'Bahamas':1, 'Colombia':1, 'Puerto Rico':1,
                                       'Dominican Republic':1,
                                         "New Zealand": 2, 'Australia':2,
                                         'China': 3, 'Japan':3, 'Hong Kong':3, 'South Korea':3,'Taiwan':3,'Cambodia':3,
                                       'Thailand':3, 'Kyrgyzstan':3, 'Indonesia':3,  'Iran':3, 'Afghanistan':3,
                                       'Philippines':3,
                                         'South Africa':4, 'Libya':4,'Nigeria':4,'Cameroon':4,'United Arab Emirates':4, 
                                       'Kenya':4,
                                      'India':5,'Pakistan':5,
                                      'Official site':np.nan, 'New Line':np.nan}}
X.replace(cleanup_countries, inplace=True)
# Out:
# /Users/Romain/.virtualenvs/romainvenv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Romain/.virtualenvs/romainvenv/lib/python3.6/site-packages/pandas/core/generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
X['label_country'].unique()
# Out:
# array([ 0., nan,  1.,  2.,  3.,  4.,  5.])

# %% [markdown]
# ## Duration

# %%
X['Duration']
# Out:
# 0       162 min
# 1           NaN
# 2       169 min
# 3       148 min
# 4       164 min
# 5       150 min
# 6       132 min
# 7           NaN
# 8       139 min
# 9       141 min
# 10      147 min
# 11      151 min
# 12      169 min
# 13      153 min
# 14      161 min
# 15      144 min
# 16          NaN
# 17      154 min
# 18      106 min
# 19      143 min
# 20      151 min
# 21      143 min
# 22          NaN
# 23      136 min
# 24      124 min
# 25          NaN
# 26      150 min
# 27      165 min
# 28          NaN
# 29      140 min
#          ...
# 5123        NaN
# 5124        NaN
# 5125        NaN
# 5126        NaN
# 5127        NaN
# 5128        NaN
# 5129        NaN
# 5130        NaN
# 5131        NaN
# 5132    108 min
# 5133        NaN
# 5134        NaN
# 5135        NaN
# 5136        NaN
# 5137        NaN
# 5138        NaN
# 5139        NaN
# 5140        NaN
# 5141        NaN
# 5142        NaN
# 5143        NaN
# 5144        NaN
# 5145        NaN
# 5146        NaN
# ...

# %%
X['Duration'].str.split(' ',1)
# Out:
# 0       [162, min]
# 1              NaN
# 2       [169, min]
# 3       [148, min]
# 4       [164, min]
# 5       [150, min]
# 6       [132, min]
# 7              NaN
# 8       [139, min]
# 9       [141, min]
# 10      [147, min]
# 11      [151, min]
# 12      [169, min]
# 13      [153, min]
# 14      [161, min]
# 15      [144, min]
# 16             NaN
# 17      [154, min]
# 18      [106, min]
# 19      [143, min]
# 20      [151, min]
# 21      [143, min]
# 22             NaN
# 23      [136, min]
# 24      [124, min]
# 25             NaN
# 26      [150, min]
# 27      [165, min]
# 28             NaN
# 29      [140, min]
#            ...
# 5123           NaN
# 5124           NaN
# 5125           NaN
# 5126           NaN
# 5127           NaN
# 5128           NaN
# 5129           NaN
# 5130           NaN
# 5131           NaN
# 5132    [108, min]
# 5133           NaN
# 5134           NaN
# 5135           NaN
# 5136           NaN
# 5137           NaN
# 5138           NaN
# ...

# %%
X = X.join(X['Duration'].str.split(' ', 1, expand=True).rename(columns={0:'Duration_movie', 1:'Trash'}))

# %%
X['Duration_movie'] = pd.to_numeric(X['Duration_movie'])

# %% [markdown]
# ## Language

# %%
X['Language'].unique()
# Out:
# array(['English', nan, 'Japanese', 'French', 'Mandarin', 'Aboriginal',
#        'Spanish', 'Filipino', 'Hindi', 'Russian', 'Maya', 'Telugu',
#        'Kazakh', 'Cantonese', 'Icelandic', 'German', 'Aramaic', 'Italian',
#        'Dutch', 'Dari', 'Chinese', 'Mongolian', 'Swedish', 'Korean',
#        'Thai', 'Polish', 'Bosnian', 'None', 'Hungarian', 'Portuguese',
#        'Danish', 'Arabic', 'Norwegian', 'Czech', 'Kannada', 'Zulu',
#        'Punjabi', 'Hebrew', 'Tamil', 'Dzongkha', 'Vietnamese',
#        'Indonesian', 'Urdu', 'Romanian', 'Persian', 'Slovenian', 'Greek',
#        'Swahili'], dtype=object)

# %%
X['label_language'] = X['Language']
cleanup_languages = {"label_language": {'English':0,'Japanese':1, 'French':2, 'Mandarin':3, 'Aboriginal':7,
       'Spanish':4, 'Filipino':7, 'Hindi':5, 'Russian':7, 'Maya':7, 'Telugu':7,
       'Kazakh':7, 'Cantonese':7, 'Icelandic':7, 'German':6, 'Aramaic':7, 'Italian':7,
       'Dutch':7, 'Dari':7, 'Chinese':7, 'Mongolian':7, 'Swedish':7, 'Korean':7,
       'Thai':7, 'Polish':7, 'Bosnian':7, 'None':np.nan, 'Hungarian':7, 'Portuguese':7,
       'Danish':7, 'Arabic':7, 'Norwegian':7, 'Czech':7, 'Kannada':7, 'Zulu':7,
       'Punjabi':7, 'Hebrew':7, 'Tamil':7, 'Dzongkha':7, 'Vietnamese':7,
       'Indonesian':7, 'Urdu':7, 'Romanian':7, 'Persian':7, 'Slovenian':7, 'Greek':7,
       'Swahili':7}}
X.replace(cleanup_languages, inplace=True)

# %%
X['label_language'].value_counts()
# Out:
# 0.0    4763
# 7.0     126
# 2.0      81
# 4.0      42
# 5.0      28
# 3.0      27
# 6.0      19
# 1.0      19
# Name: label_language, dtype: int64

# %% [markdown]
# ## Genres

# %%
X['Genres']
# Out:
# 0           ['Action', 'Adventure', 'Fantasy']
# 1                              ['Documentary']
# 2           ['Action', 'Adventure', 'Fantasy']
# 3          ['Action', 'Adventure', 'Thriller']
# 4                       ['Action', 'Thriller']
# 5           ['Action', 'Adventure', 'Western']
# 6            ['Action', 'Adventure', 'Sci-Fi']
# 7         ['Animation', 'Adventure', 'Comedy']
# 8            ['Action', 'Adventure', 'Sci-Fi']
# 9            ['Action', 'Adventure', 'Sci-Fi']
# 10           ['Action', 'Adventure', 'Sci-Fi']
# 11          ['Action', 'Adventure', 'Fantasy']
# 12          ['Adventure', 'Family', 'Fantasy']
# 13          ['Adventure', 'Family', 'Fantasy']
# 14                    ['Adventure', 'Fantasy']
# 15                    ['Adventure', 'Fantasy']
# 16          ['Action', 'Adventure', 'Fantasy']
# 17           ['Action', 'Adventure', 'Sci-Fi']
# 18         ['Action', 'Adventure', 'Thriller']
# 19           ['Action', 'Adventure', 'Sci-Fi']
# ...

# %%
X.join(X['Genres'].str.split(',', 1, expand=True).rename(columns={0:'Genre_1', 1:'Genre_2',2:'Genre_3'}))
# Out:
#      Actor_1_like Actor_2_like Actor_3_like       Budget      Country  \
# 0             5.3          NaN          5.3  237000000.0           UK
# 1              13            1          NaN          NaN          NaN
# 2              40          5.1           40  300000000.0          USA
# 3             8.5           11          8.5  245000000.0           UK
# 4             NaN          NaN          NaN  250000000.0           UK
# 5              40          5.5           40  215000000.0          USA
# 6             5.6          1.8          5.6  250000000.0          USA
# 7             2.2         this          2.2  260000000.0          USA
# 8             2.9          4.1          2.9  258000000.0          USA
# 9               1           11            1  250000000.0          USA
# 10             11            1           11  250000000.0          USA
# 11            6.9           15          6.9  250000000.0          USA
# ...

# %%
df2 = pd.DataFrame(X['Genres'].str.split().values.tolist())

# %%
X['Genres'].value_counts()
# Out:
# ['Drama']                                    229
# ['Comedy', 'Drama', 'Romance']               214
# ['Comedy']                                   208
# ['Comedy', 'Drama']                          186
# ['Comedy', 'Romance']                        155
# ['Drama', 'Romance']                         148
# ['Action', 'Crime', 'Drama']                 118
# ['Animation', 'Adventure', 'Comedy']         114
# ['Crime', 'Drama', 'Thriller']               102
# ['Action', 'Adventure', 'Sci-Fi']             96
# ['Action', 'Comedy', 'Crime']                 81
# ['Action', 'Adventure', 'Comedy']             77
# ['Crime', 'Drama', 'Mystery']                 76
# ['Horror', 'Thriller']                        73
# ['Action', 'Adventure', 'Drama']              71
# ['Action', 'Adventure', 'Fantasy']            69
# ['Crime', 'Drama']                            63
# ['Drama', 'Thriller']                         62
# ['Action', 'Crime', 'Thriller']               62
# ...

# %%
def isAction(row):
    if 'Action' in row.Genres:
        return 1;
    else:
        return 0;
    
def isAdventure(row):
    if 'Adventure' in row.Genres:
        return 1;
    else:
        return 0;
    
def isAnimation(row):
    if 'Animation' in row.Genres:
        return 1;
    else:
        return 0;
    
def isBiography(row):
    if 'Biography' in row.Genres:
        return 1;
    else:
        return 0;
    
def isComedy(row):
    if 'Comedy' in row.Genres:
        return 1;
    else:
        return 0;
    
def isCrime(row):
    if 'Crime' in row.Genres:
        return 1;
    else:
        return 0;
    
def isFantasy(row):
    if 'Fantasy' in row.Genres:
        return 1;
    else:
        return 0;

def isDocumentary(row):
    if 'Documentary' in row.Genres:
        return 1;
    else:
        return 0;
    
def isFamily(row):
    if 'Family' in row.Genres:
        return 1;
    else:
        return 0;
    
def isDrama(row):
    if 'Drama' in row.Genres:
        return 1;
    else:
        return 0;
    
def isHistory(row):
    if 'History' in row.Genres:
        return 1;
    else:
        return 0;
    
def isHorror(row):
    if 'Horror' in row.Genres:
        return 1;
    else:
        return 0;
    
def isMusic(row):
    if 'Music' in row.Genres:
        return 1;
    else:
        return 0;
    
def isMystery(row):
    if 'Mystery' in row.Genres:
        return 1;
    else:
        return 0;
    
def isRomance(row):
    if 'Romance' in row.Genres:
        return 1;
    else:
        return 0;
    
def isSciFi(row):
    if 'Sci-Fi' in row.Genres:
        return 1;
    else:
        return 0;
    
def isThriller(row):
    if 'Thriller' in row.Genres:
        return 1;
    else:
        return 0;
    
def isSport(row):
    if 'Sport' in row.Genres:
        return 1;
    else:
        return 0;
    
def isSuperhero(row):
    if 'Superhero' in row.Genres:
        return 1;
    else:
        return 0;
    
def isWar(row):
    if 'War' in row.Genres:
        return 1;
    else:
        return 0;
    
def isWestern(row):
    if 'Western' in row.Genres:
        return 1;
    else:
        return 0;

# %%
X['isAction'] = X.apply(lambda row: isAction(row), axis = 1)
X['isAdventure'] = X.apply(lambda row: isAdventure(row), axis = 1)
X['isAnimation'] = X.apply(lambda row: isAnimation(row), axis = 1)
X['isBiography'] = X.apply(lambda row: isBiography(row), axis = 1)
X['isComedy'] = X.apply(lambda row: isComedy(row), axis = 1)
X['isCrime'] = X.apply(lambda row: isCrime(row), axis = 1)
X['isFantasy'] = X.apply(lambda row: isFantasy(row), axis = 1)
X['isDocumentary'] = X.apply(lambda row: isDocumentary(row), axis = 1)
X['isFamily'] = X.apply(lambda row: isFamily(row), axis = 1)
X['isDrama'] = X.apply(lambda row: isDrama(row), axis = 1)
X['isHistory'] = X.apply(lambda row: isHistory(row), axis = 1)
X['isHorror'] = X.apply(lambda row: isHorror(row), axis = 1)
X['isMusic'] = X.apply(lambda row: isMusic(row), axis = 1)
X['isMystery'] = X.apply(lambda row: isMystery(row), axis = 1)
X['isRomance'] = X.apply(lambda row: isRomance(row), axis = 1)
X['isSciFi'] = X.apply(lambda row: isSciFi(row), axis = 1)
X['isThriller'] = X.apply(lambda row: isThriller(row), axis = 1)
X['isSport'] = X.apply(lambda row: isSport(row), axis = 1)
X['isSuperhero'] = X.apply(lambda row: isSuperhero(row), axis = 1)
X['isWar'] = X.apply(lambda row: isWar(row), axis = 1)
X['isWestern'] = X.apply(lambda row: isWestern(row), axis = 1)

# %%
X.sum()
# Out:
# Budget            1.509248e+11
# Year              1.000676e+07
# label_country     4.669000e+03
# Duration_movie    2.217080e+05
# label_language    1.566000e+03
# isAction          1.203000e+03
# isAdventure       9.780000e+02
# isAnimation       2.500000e+02
# isBiography       3.170000e+02
# isComedy          1.890000e+03
# isCrime           9.130000e+02
# isFantasy         4.130000e+02
# isDocumentary     1.270000e+02
# isFamily          3.610000e+02
# isDrama           2.622000e+03
# isHistory         1.780000e+02
# isHorror          5.620000e+02
# isMusic           2.450000e+02
# isMystery         4.280000e+02
# isRomance         8.750000e+02
# isSciFi           4.100000e+02
# isThriller        7.880000e+02
# isSport           1.320000e+02
# isSuperhero       0.000000e+00
# isWar             1.090000e+02
# isWestern         5.100000e+01
# dtype: float64

# %% [markdown]
# Superhero is useless

# %%
del X['isSuperhero']

# %% [markdown]
# ## Keywords & Storyline
